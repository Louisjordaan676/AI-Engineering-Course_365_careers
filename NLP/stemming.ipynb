# %% [markdown]
# Stemming: reducing words to their base form.
#
# - reduces complexity
# - keeps the dataset easier to manage

# %%
from nltk.stem import PorterStemmer

# %%
ps = PorterStemmer()

# %%
connect_tokens = ['connecting', 'connected', 'connectivity', 'connect', 'connects']

# %%
for t in connect_tokens:
    print(t, ": ", ps.stem(t))
# Out:
# connecting :  connect
# connected :  connect
# connectivity :  connect
# connect :  connect
# connects :  connect

# %%
learn_tokens = ['learned', 'learning', 'learn', 'learns', 'learner', 'learners']

# %%
for l in learn_tokens:
    print(f"{l}: {ps.stem(l)}")
# Out:
# learned: learn
# learning: learn
# learn: learn
# learns: learn
# learner: learner
# learners: learner

# %%
likes_tokens = ['likes', 'better', 'worse']

# %%
for t in likes_tokens:
    print(f"{t}: {ps.stem(t)}")

# the output of stemming is not always meaningful. worse became wors which is not a word...
# Out:
# likes: like
# better: better
# worse: wors
